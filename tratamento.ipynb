# %%
import pandas as pd

# %%
df = pd.read_json('vagas.json')
df.head()
# Out:
#    id_da_vaga                                     titulo_da_vaga  \
# 0     9919664                           Atendente De Restaurante
# 1     9919656  Auxiliar De Vendas / Vendedor - São Paulo  - (AJ)
# 2     9919657                      Esteticista Corporal E Facial
# 3     9516089                            Auxiliar Administrativo
# 4     9919650  Assistente Contábil Financeiro Pleno - Presenc...
#
#                               nome_da_empresa  local_da_empresa  \
# 0                    AMARELINHO CAFE E LANCHE  Santo André - SP
# 1                        Empresa confidencial    São Paulo - SP
# 2                                    EMPREGGA    São Paulo - SP
# 3                         CONSULTORIA SOGNARE    São Paulo - SP
# 4  D A - Assessoria em Recrutamento & Seleção    São Paulo - SP
#
#   modelo_de_trabalho                               tipo_de_contrato  \
# 0         Presencial  Prestador de Serviços (PJ) - Período Integral
# ...

# %% [markdown]
# ### SEPARAR CIDADE DE ESTADO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160 entries, 0 to 159
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_da_vaga          160 non-null    int64
#  1   titulo_da_vaga      160 non-null    object
#  2   nome_da_empresa     160 non-null    object
#  3   local_da_empresa    160 non-null    object
#  4   modelo_de_trabalho  160 non-null    object
#  5   tipo_de_contrato    160 non-null    object
#  6   faixa_salarial      160 non-null    object
#  7   descricao_da_vaga   160 non-null    object
#  8   exigencias          160 non-null    object
#  9   valorizado          160 non-null    object
#  10  beneficios          160 non-null    object
#  11  habilidades         160 non-null    object
#  12  url_da_vaga         160 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 16.4+ KB
